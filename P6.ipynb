# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# # part A

# %%
img = cv2.imread("tetris.png")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img_1 = img

img_t = cv2.imread("T.png")
img_t = cv2.cvtColor(img_t, cv2.COLOR_BGR2RGB)

img_1[100:200,500:600,] = img_t[0:100,200:300,]

img_1 = cv2.cvtColor(img_1, cv2.COLOR_RGB2BGR)
cv2.imwrite('tet001.png', img_1)

img_1 = cv2.cvtColor(img_1, cv2.COLOR_BGR2RGB)
plt.imshow(img_1)

# %%
img_1[100:200,500:600,] = (0,0,0)
img_1[100:200,400:700,] = img_t[0:100,0:300,]
img_1[200:300,500:600,] = img_t[100:200,100:200,]

img_1 = cv2.cvtColor(img_1, cv2.COLOR_RGB2BGR)
cv2.imwrite('tet002.png', img_1)
img_1 = cv2.cvtColor(img_1, cv2.COLOR_BGR2RGB)


plt.imshow(img_1)

# %%
img_1[200:400,400:700,] = img_1[100:300,400:700,]
img_1[100:200,400:700,] = (0,0,0)

img_1 = cv2.cvtColor(img_1, cv2.COLOR_RGB2BGR)
cv2.imwrite('tet003.png', img_1)
img_1 = cv2.cvtColor(img_1, cv2.COLOR_BGR2RGB)

plt.imshow(img_1)

# %%
img_1[300:500,400:700,] = img_1[200:400,400:700,] 
img_1[200:300,400:700,]  = (0,0,0)

img_1 = cv2.cvtColor(img_1, cv2.COLOR_RGB2BGR)
cv2.imwrite('tet004.png', img_1)
img_1 = cv2.cvtColor(img_1, cv2.COLOR_BGR2RGB)

plt.imshow(img_1)

# %%
img_1[400:600,400:700,] = img_1[300:500,400:700,]  
img_1[300:400,400:700,]  = (0,0,0)

img_1 = cv2.cvtColor(img_1, cv2.COLOR_RGB2BGR)
cv2.imwrite('tet005.png', img_1)
img_1 = cv2.cvtColor(img_1, cv2.COLOR_BGR2RGB)


plt.imshow(img_1)

# %%
img_1[500:700,400:700,] = img_1[400:600,400:700,]
img_1[400:500,400:700,]  = (0,0,0)

img_1 = cv2.cvtColor(img_1, cv2.COLOR_RGB2BGR)
cv2.imwrite('tet006.png', img_1)
img_1 = cv2.cvtColor(img_1, cv2.COLOR_BGR2RGB)


plt.imshow(img_1)

# %%
img_1[600:800,400:700,] = img_1[500:700,400:700,]
img_1[500:600,400:700,]  = (0,0,0)

img_1 = cv2.cvtColor(img_1, cv2.COLOR_RGB2BGR)
cv2.imwrite('tet007.png', img_1)
img_1 = cv2.cvtColor(img_1, cv2.COLOR_BGR2RGB)

plt.imshow(img_1)

# %%
img_1[700:900,400:700,] = img_1[600:800,400:700,]
img_1[600:700,400:700,]  = (0,0,0)

img_1 = cv2.cvtColor(img_1, cv2.COLOR_RGB2BGR)
cv2.imwrite('tet008.png', img_1)
img_1 = cv2.cvtColor(img_1, cv2.COLOR_BGR2RGB)


plt.imshow(img_1)

# %%
img_1[800:1000,400:700,] = img_1[700:900,400:700,] 
img_1[700:800,400:700,]  = (0,0,0)

img_1 = cv2.cvtColor(img_1, cv2.COLOR_RGB2BGR)
cv2.imwrite('tet009.png', img_1)
img_1 = cv2.cvtColor(img_1, cv2.COLOR_BGR2RGB)

plt.imshow(img_1)

# %%
img_1[900:1100,400:700,] = img_1[800:1000,400:700,]
img_1[800:900,400:700,]  = (0,0,0)

img_1 = cv2.cvtColor(img_1, cv2.COLOR_RGB2BGR)
cv2.imwrite('tet010.png', img_1)
img_1 = cv2.cvtColor(img_1, cv2.COLOR_BGR2RGB)

plt.imshow(img_1)

# %%
img_1[1000:1200,400:700,] = img_1[900:1100,400:700,]
img_1[900:1000,400:700,]  = (0,0,0)

img_1 = cv2.cvtColor(img_1, cv2.COLOR_RGB2BGR)
cv2.imwrite('tet011.png', img_1)
img_1 = cv2.cvtColor(img_1, cv2.COLOR_BGR2RGB)

plt.imshow(img_1)

# %% [markdown]
# # part B

# %%
img_L = cv2.imread("L.png")
img_L = cv2.cvtColor(img_L, cv2.COLOR_BGR2RGB)
img_1[100:200,400:600,] = img_L[200:300,0:200,]

img_1 = cv2.cvtColor(img_1, cv2.COLOR_RGB2BGR)
cv2.imwrite('tet012.png', img_1)
img_1 = cv2.cvtColor(img_1, cv2.COLOR_BGR2RGB)

plt.imshow(img_1)

# %%
img_L = cv2.imread("L.png")
img_L = cv2.cvtColor(img_L, cv2.COLOR_BGR2RGB)
img_1[100:200,500:600,] = (0,0,0)
img_1[100:200,400:500,] = img_L[100:200,0:100,]
img_1[200:300,400:600,] = img_L[200:300,0:200,]

img_1 = cv2.cvtColor(img_1, cv2.COLOR_RGB2BGR)
cv2.imwrite('tet013.png', img_1)
img_1 = cv2.cvtColor(img_1, cv2.COLOR_BGR2RGB)

plt.imshow(img_1)

# %%
img_L = cv2.imread("L.png")
img_L = cv2.cvtColor(img_L, cv2.COLOR_BGR2RGB)
img_1[200:300,500:600,] = (0,0,0)
img_1[100:200,400:500,] = img_L[100:200,0:100,]
img_1[200:300,400:500,] = img_L[100:200,0:100,]
img_1[300:400,400:600,] = img_L[200:300,0:200,]

img_1 = cv2.cvtColor(img_1, cv2.COLOR_RGB2BGR)
cv2.imwrite('tet014.png', img_1)
img_1 = cv2.cvtColor(img_1, cv2.COLOR_BGR2RGB)

plt.imshow(img_1)

# %%
img_1[200:500,400:600,] = img_1[100:400,400:600,]
img_1[100:200,400:600,] = (0,0,0)

img_1 = cv2.cvtColor(img_1, cv2.COLOR_RGB2BGR)
cv2.imwrite('tet015.png', img_1)
img_1 = cv2.cvtColor(img_1, cv2.COLOR_BGR2RGB)

plt.imshow(img_1)

# %%
img_1[300:600,400:600,] = img_1[200:500,400:600,]
img_1[200:300,400:600,] = (0,0,0)

img_1 = cv2.cvtColor(img_1, cv2.COLOR_RGB2BGR)
cv2.imwrite('tet016.png', img_1)
img_1 = cv2.cvtColor(img_1, cv2.COLOR_BGR2RGB)

plt.imshow(img_1)

# %%
img_1[400:700,400:600,] = img_1[300:600,400:600,]
img_1[300:400,400:600,] = (0,0,0)
img_1[500:600,500:600,] = (0,0,0)

img_1 = cv2.cvtColor(img_1, cv2.COLOR_RGB2BGR)
cv2.imwrite('tet017.png', img_1)
img_1 = cv2.cvtColor(img_1, cv2.COLOR_BGR2RGB)

plt.imshow(img_1)

# %%
img_1[500:800,400:600,] = img_1[400:700,400:600,]
img_1[400:500,400:600,] = (0,0,0)

img_1 = cv2.cvtColor(img_1, cv2.COLOR_RGB2BGR)
cv2.imwrite('tet018.png', img_1)
img_1 = cv2.cvtColor(img_1, cv2.COLOR_BGR2RGB)

plt.imshow(img_1)

# %%
img_1[600:900,400:600,] = img_1[500:800,400:600,]
img_1[500:600,400:600,] = (0,0,0)

img_1 = cv2.cvtColor(img_1, cv2.COLOR_RGB2BGR)
cv2.imwrite('tet019.png', img_1)
img_1 = cv2.cvtColor(img_1, cv2.COLOR_BGR2RGB)

plt.imshow(img_1)

# %%
img_1[600:1000,400:600,] = img_1[500:900,400:600,] 

img_1 = cv2.cvtColor(img_1, cv2.COLOR_RGB2BGR)
cv2.imwrite('tet020.png', img_1)
img_1 = cv2.cvtColor(img_1, cv2.COLOR_BGR2RGB)

plt.imshow(img_1)

# %% [markdown]
# # part C

# %%
img_S = cv2.imread("S.png")
img_1[100:200,400:600,] = img_S[100:200,0:200,]

img_1 = cv2.cvtColor(img_1, cv2.COLOR_RGB2BGR)
cv2.imwrite('tet021.png', img_1)
img_1 = cv2.cvtColor(img_1, cv2.COLOR_BGR2RGB)

plt.imshow(img_1)

# %%
img_S = cv2.imread("S.png")
img_1[100:200,400:600,] = (0,0,0)
img_1[100:200,500:700,] = img_S[0:100,100:300,]
img_1[200:300,400:600,] = img_S[100:200,0:200,]

img_1 = cv2.cvtColor(img_1, cv2.COLOR_RGB2BGR)
cv2.imwrite('tet022.png', img_1)
img_1 = cv2.cvtColor(img_1, cv2.COLOR_BGR2RGB)

plt.imshow(img_1)

# %%
img_S = cv2.imread("S.png")
img_1[100:200,400:700,] = (0,0,0)
img_1[200:300,400:600,] = img_S[0:100,100:300,]
img_1[300:400,300:500,] = img_S[100:200,0:200,]

img_1 = cv2.cvtColor(img_1, cv2.COLOR_RGB2BGR)
cv2.imwrite('tet023.png', img_1)
img_1 = cv2.cvtColor(img_1, cv2.COLOR_BGR2RGB)

plt.imshow(img_1)

# %%
img_1[200:300,400:700,] = (0,0,0)
img_1[300:400,300:500,] = img_S[0:100,100:300,]
img_1[400:500,200:400,] = img_S[100:200,0:200,]

img_1 = cv2.cvtColor(img_1, cv2.COLOR_RGB2BGR)
cv2.imwrite('tet024.png', img_1)
img_1 = cv2.cvtColor(img_1, cv2.COLOR_BGR2RGB)

plt.imshow(img_1)

# %%
img_1[300:400,300:700,] = (0,0,0)
img_1[400:500,200:700,] = (0,0,0)
img_1[400:500,300:500,] = img_S[0:100,100:300,]
img_1[500:600,200:400,] = img_S[100:200,0:200,]

img_1 = cv2.cvtColor(img_1, cv2.COLOR_RGB2BGR)
cv2.imwrite('tet025.png', img_1)
img_1 = cv2.cvtColor(img_1, cv2.COLOR_BGR2RGB)


plt.imshow(img_1)

# %%
img_1[400:500,300:700,] = (0,0,0)
img_1[500:600,200:700,] = (0,0,0)
img_1[500:600,300:500,] = img_S[0:100,100:300,]
img_1[600:700,200:400,] = img_S[100:200,0:200,]

img_1 = cv2.cvtColor(img_1, cv2.COLOR_RGB2BGR)
cv2.imwrite('tet026.png', img_1)
img_1 = cv2.cvtColor(img_1, cv2.COLOR_BGR2RGB)

plt.imshow(img_1)

# %%
img_1[500:600,300:700,] = (0,0,0)
img_1[600:700,200:700,] = (0,0,0)
img_1[600:700,300:500,] = img_S[0:100,100:300,]
img_1[700:800,200:400,] = img_S[100:200,0:200,]

img_1 = cv2.cvtColor(img_1, cv2.COLOR_RGB2BGR)
cv2.imwrite('tet027.png', img_1)
img_1 = cv2.cvtColor(img_1, cv2.COLOR_BGR2RGB)

plt.imshow(img_1)

# %% [markdown]
# # part d

# %%
img_I = cv2.imread("I.png")
img_I = cv2.cvtColor(img_I, cv2.COLOR_BGR2RGB)
plt.imshow(img_I)

# %%
img_1[100:200,500:600,] = img_I[0:100,0:100,]

img_1 = cv2.cvtColor(img_1, cv2.COLOR_RGB2BGR)
cv2.imwrite('tet028.png', img_1)
img_1 = cv2.cvtColor(img_1, cv2.COLOR_BGR2RGB)

plt.imshow(img_1)

# %%
img_1[100:200,500:600,] = (0,0,0)
img_1[100:200,600:700,] = img_I[0:100,0:100,]
img_1[200:300,600:700,] = img_I[0:100,0:100,]

img_1 = cv2.cvtColor(img_1, cv2.COLOR_RGB2BGR)
cv2.imwrite('tet029.png', img_1)
img_1 = cv2.cvtColor(img_1, cv2.COLOR_BGR2RGB)


plt.imshow(img_1)

# %%
img_1[100:200,600:700,] = (0,0,0)
img_1[200:300,600:700,] = (0,0,0)
img_1[100:200,700:800,] = img_I[0:100,0:100,]
img_1[200:300,700:800,] = img_I[0:100,0:100,]
img_1[300:400,700:800,] = img_I[0:100,0:100,]

img_1 = cv2.cvtColor(img_1, cv2.COLOR_RGB2BGR)
cv2.imwrite('tet030.png', img_1)
img_1 = cv2.cvtColor(img_1, cv2.COLOR_BGR2RGB)


plt.imshow(img_1)

# %%
img_1[100:200,700:800,] = (0,0,0)
img_1[200:300,700:800,] = (0,0,0)
img_1[300:400,700:800,] = (0,0,0)
img_1[100:200,800:900,] = img_I[0:100,0:100,]
img_1[200:300,800:900,] = img_I[0:100,0:100,]
img_1[300:400,800:900,] = img_I[0:100,0:100,]
img_1[400:500,800:900,] = img_I[0:100,0:100,]

img_1 = cv2.cvtColor(img_1, cv2.COLOR_RGB2BGR)
cv2.imwrite('tet031.png', img_1)
img_1 = cv2.cvtColor(img_1, cv2.COLOR_BGR2RGB)


plt.imshow(img_1)

# %%
img_1[100:200,800:900,] = (0,0,0)
img_1[200:300,800:900,] = (0,0,0)
img_1[300:400,800:900,] = (0,0,0)
img_1[400:500,800:900,] = (0,0,0)

img_1[500:600,900:1000,] = img_I[0:100,0:100,]
img_1[200:300,900:1000,] = img_I[0:100,0:100,]
img_1[300:400,900:1000,] = img_I[0:100,0:100,]
img_1[400:500,900:1000,] = img_I[0:100,0:100,]

img_1 = cv2.cvtColor(img_1, cv2.COLOR_RGB2BGR)
cv2.imwrite('tet032.png', img_1)
img_1 = cv2.cvtColor(img_1, cv2.COLOR_BGR2RGB)


plt.imshow(img_1)

# %%
img_1[500:600,900:1000,] = (0,0,0)
img_1[200:300,900:1000,] = (0,0,0)
img_1[300:400,900:1000,] = (0,0,0)
img_1[400:500,900:1000,] = (0,0,0)

img_1[500:600,1000:1100,] = img_I[0:100,0:100,]
img_1[600:700,1000:1100,] = img_I[0:100,0:100,]
img_1[300:400,1000:1100,] = img_I[0:100,0:100,]
img_1[400:500,1000:1100,] = img_I[0:100,0:100,]

img_1 = cv2.cvtColor(img_1, cv2.COLOR_RGB2BGR)
cv2.imwrite('tet033.png', img_1)
img_1 = cv2.cvtColor(img_1, cv2.COLOR_BGR2RGB)


plt.imshow(img_1)

# %%
img_1[500:600,1000:1100,] = (0,0,0)
img_1[600:700,1000:1100,] = (0,0,0)
img_1[300:400,1000:1100,] = (0,0,0)
img_1[400:500,1000:1100,] = (0,0,0)

img_1[500:600,1000:1100,] = img_I[0:100,0:100,]
img_1[600:700,1000:1100,] = img_I[0:100,0:100,]
img_1[700:800,1000:1100,] = img_I[0:100,0:100,]
img_1[400:500,1000:1100,] = img_I[0:100,0:100,]

img_1 = cv2.cvtColor(img_1, cv2.COLOR_RGB2BGR)
cv2.imwrite('tet034.png', img_1)
img_1 = cv2.cvtColor(img_1, cv2.COLOR_BGR2RGB)

plt.imshow(img_1)

# %%
img_1[500:600,1000:1100,] = (0,0,0)
img_1[600:700,1000:1100,] = (0,0,0)
img_1[700:800,1000:1100,] = (0,0,0)
img_1[400:500,1000:1100,] = (0,0,0)

img_1[500:600,1000:1100,] = img_I[0:100,0:100,]
img_1[600:700,1000:1100,] = img_I[0:100,0:100,]
img_1[700:800,1000:1100,] = img_I[0:100,0:100,]
img_1[800:900,1000:1100,] = img_I[0:100,0:100,]

img_1 = cv2.cvtColor(img_1, cv2.COLOR_RGB2BGR)
cv2.imwrite('tet035.png', img_1)
img_1 = cv2.cvtColor(img_1, cv2.COLOR_BGR2RGB)


plt.imshow(img_1)

# %%
img_1[500:600,1000:1100,] = (0,0,0)
img_1[600:700,1000:1100,] = (0,0,0)
img_1[700:800,1000:1100,] = (0,0,0)
img_1[800:900,1000:1100,] = (0,0,0)


img_1[900:1000,1000:1100,] = img_I[0:100,0:100,]
img_1[600:700,1000:1100,] = img_I[0:100,0:100,]
img_1[700:800,1000:1100,] = img_I[0:100,0:100,]
img_1[800:900,1000:1100,] = img_I[0:100,0:100,]

img_1 = cv2.cvtColor(img_1, cv2.COLOR_RGB2BGR)
cv2.imwrite('tet036.png', img_1)
img_1 = cv2.cvtColor(img_1, cv2.COLOR_BGR2RGB)


plt.imshow(img_1)

# %%
img_1[900:1000,1000:1100,] = (0,0,0)
img_1[600:700,1000:1100,] = (0,0,0)
img_1[700:800,1000:1100,] = (0,0,0)
img_1[800:900,1000:1100,] = (0,0,0)


img_1[900:1000,1000:1100,] = img_I[0:100,0:100,]
img_1[1000:1100,1000:1100,] = img_I[0:100,0:100,]
img_1[700:800,1000:1100,] = img_I[0:100,0:100,]
img_1[800:900,1000:1100,] = img_I[0:100,0:100,]

img_1 = cv2.cvtColor(img_1, cv2.COLOR_RGB2BGR)
cv2.imwrite('tet037.png', img_1)
img_1 = cv2.cvtColor(img_1, cv2.COLOR_BGR2RGB)


plt.imshow(img_1)

# %%
img_1[900:1000,1000:1100,] = (0,0,0)
img_1[1000:1100,1000:1100,] = (0,0,0)
img_1[700:800,1000:1100,] = (0,0,0)
img_1[800:900,1000:1100,] = (0,0,0)


img_1[900:1000,1000:1100,] = img_I[0:100,0:100,]
img_1[1000:1100,1000:1100,] = img_I[0:100,0:100,]
img_1[1100:1200,1000:1100,] = img_I[0:100,0:100,]
img_1[800:900,1000:1100,] = img_I[0:100,0:100,]


img_1 = cv2.cvtColor(img_1, cv2.COLOR_RGB2BGR)
cv2.imwrite('tet038.png', img_1)
img_1 = cv2.cvtColor(img_1, cv2.COLOR_BGR2RGB)


plt.imshow(img_1)

# %%
img_1[900:1000,1000:1100,] = (0,0,0)
img_1[1000:1100,1000:1100,] = (0,0,0)
img_1[1100:1200,1000:1100,] = (0,0,0)
img_1[800:900,1000:1100,] = (0,0,0)

img_1[900:1000,1000:1100,] = img_I[0:100,0:100,]
img_1[1000:1100,1000:1100,] = img_I[0:100,0:100,]
img_1[1100:1200,1000:1100,] = img_I[0:100,0:100,]
img_1[1200:1300,1000:1100,] = img_I[0:100,0:100,]

img_1 = cv2.cvtColor(img_1, cv2.COLOR_RGB2BGR)
cv2.imwrite('tet039.png', img_1)
img_1 = cv2.cvtColor(img_1, cv2.COLOR_BGR2RGB)


plt.imshow(img_1)

# %%
index = 0
for i in range(8):
    img_1[900+index:1300+index,1000:1100,] = (0,0,0)
    img_1[1000+index:1400+index,1000:1100,] = img_I
    
    img_1 = cv2.cvtColor(img_1, cv2.COLOR_RGB2BGR)
    cv2.imwrite('tet0'+str(40+i)+'.png', img_1)
    img_1 = cv2.cvtColor(img_1, cv2.COLOR_BGR2RGB)
    plt.imshow(img_1)
    index+=100

# %%
img_1[1700:2100,100:1100,] = (0,0,0)
plt.imshow(img_1)

img_1 = cv2.cvtColor(img_1, cv2.COLOR_RGB2BGR)
cv2.imwrite('tet048.png', img_1)
img_1 = cv2.cvtColor(img_1, cv2.COLOR_BGR2RGB)

# %%
img_1[1700:2100,100:1100,] = (0,0,0)
img_1[950:2100,100:1100,] = img_1[550:1700,100:1100,] 
img_1[550:950,100:1100,] = (0,0,0)


img_1 = cv2.cvtColor(img_1, cv2.COLOR_RGB2BGR)
cv2.imwrite('tet049.png', img_1)
img_1 = cv2.cvtColor(img_1, cv2.COLOR_BGR2RGB)


plt.imshow(img_1)

# %% [markdown]
# # part E

# %%
img_O = cv2.imread("O.png")
img_O = cv2.cvtColor(img_O, cv2.COLOR_BGR2RGB)
plt.imshow(img_O)

# %%
img_1[100:200,500:700,] = img_O[100:200,0:200,]

img_1 = cv2.cvtColor(img_1, cv2.COLOR_RGB2BGR)
cv2.imwrite('tet050.png', img_1)
img_1 = cv2.cvtColor(img_1, cv2.COLOR_BGR2RGB)

plt.imshow(img_1)

# %%
img_1[100:300,600:800,] = img_O[:,0:,]
img_1[100:200,400:600,] = (0,0,0)

img_1 = cv2.cvtColor(img_1, cv2.COLOR_RGB2BGR)
cv2.imwrite('tet051.png', img_1)
img_1 = cv2.cvtColor(img_1, cv2.COLOR_BGR2RGB)


plt.imshow(img_1)

# %%
img_1[100:300,600:800,] = (0,0,0)
img_1[200:400,700:900,] = img_O[:,0:,]

img_1 = cv2.cvtColor(img_1, cv2.COLOR_RGB2BGR)
cv2.imwrite('tet052.png', img_1)
img_1 = cv2.cvtColor(img_1, cv2.COLOR_BGR2RGB)


plt.imshow(img_1)

# %%
img_1[200:400,700:900,] = (0,0,0)
img_1[300:500,800:1000,] = img_O[:,0:,]

img_1 = cv2.cvtColor(img_1, cv2.COLOR_RGB2BGR)
cv2.imwrite('tet053.png', img_1)
img_1 = cv2.cvtColor(img_1, cv2.COLOR_BGR2RGB)


plt.imshow(img_1)

# %%
img_1[300:500,800:1000,] = (0,0,0)
img_1[400:600,900:1100,] = img_O[:,0:,]

img_1 = cv2.cvtColor(img_1, cv2.COLOR_RGB2BGR)
cv2.imwrite('tet054.png', img_1)
img_1 = cv2.cvtColor(img_1, cv2.COLOR_BGR2RGB)


plt.imshow(img_1)

# %%
index = 100
for i in range(15):
    img_1[(300+index):(500+index),900:1100,] = (0,0,0)
    img_1[(400+index):(600+index),900:1100,] = img_O[:,:,]
    img_1 = cv2.cvtColor(img_1, cv2.COLOR_RGB2BGR)
    cv2.imwrite('tet0'+str(55+i)+'.png', img_1)
    img_1 = cv2.cvtColor(img_1, cv2.COLOR_BGR2RGB)
    plt.imshow(img_1)
    index+=100

# %%
img_1[2000:2100,100:1100,] = (0,0,0)

img_1 = cv2.cvtColor(img_1, cv2.COLOR_RGB2BGR)
cv2.imwrite('tet070.png', img_1)
img_1 = cv2.cvtColor(img_1, cv2.COLOR_BGR2RGB)
plt.imshow(img_1)

# %%
img_1[1000:2100,100:1100,]= img_1[900:2000,100:1100,]
img_1 = cv2.cvtColor(img_1, cv2.COLOR_RGB2BGR)
cv2.imwrite('tet071.png', img_1)
img_1 = cv2.cvtColor(img_1, cv2.COLOR_BGR2RGB)
plt.imshow(img_1)

# %% [markdown]
# # part F

# %%
import numpy as np
import glob
 
img_array = []
size  = (0,0)
for filename in glob.glob('Image/*.png'):
    img = cv2.imread(filename)
    height, width, layers = img.shape
    size = (width,height)
    img_array.append(img)
 
 
out = cv2.VideoWriter('project.avi',cv2.VideoWriter_fourcc(*'DIVX'), 2, size)
 
for i in range(len(img_array)):
    out.write(img_array[i])
    
out.release()
